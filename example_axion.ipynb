# %%
from classy import Class
import os
import copy
import yaml
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

from matplotlib import rc
from scipy.interpolate import interp1d

rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
#matplotlib.rc('font', **font)
matplotlib.rcParams['legend.fontsize']='medium'
plt.rcParams["figure.figsize"] = [8.0,6.0]

# %%
def compute_axion(m_axion,f_axion,Omega_scf):
    cosmofid = {
    'Omega_cdm':0.3,
    'H0':67,
    'Omega_scf':Omega_scf,
    'm_axion':m_axion,
    'f_axion':f_axion,
    'scf_parameters': r'%g, %g' % (0.05, 0.),
    #'scf_parameters__2': 0., 
    'scf_potential': 'axion', 
    'n_axion': 1, 
    'scf_has_perturbations': 'yes', 
    'attractor_ic_scf': 'no',
    'do_shooting': 'yes',
    'do_shooting_scf': 'yes',
    'scf_tuning_index': 0,
    'tol_shooting_deltax':1e-4,
    'tol_shooting_deltaF':1e-4,
    'background_verbose':10,
    'thermodynamics_verbose':1,
    'scf_evolve_as_fluid':'yes',
    'scf_evolve_like_axionCAMB':'yes'
    }
    M = Class()
    M.set({'output': 'mPk', 'z_max_pk': 1, 'P_k_max_h/Mpc': 1.})
    M.set(cosmofid)
    M.compute()
    background = M.get_background() # load background table
    return background, M

# %%
#fiducial axion
background_axion_1,M1 = compute_axion(1e8,0.4,0.05)
background_z_1 = background_axion_1['z'] # read redshift

##here we vary the mass
background_axion_2,M2 = compute_axion(1e10,0.4,0.05)
background_axion_3,M3 = compute_axion(1e5,0.4,0.05)

##here we vary the density
background_axion_4,M4 = compute_axion(1e8,0.4,0.15)
background_axion_5,M5 = compute_axion(1e8,0.4,0.3)

##here we vary f_a
background_axion_6,M6 = compute_axion(1e8,0.1,0.05)
background_axion_7,M7 = compute_axion(1e8,0.6,0.05)
# Out:
# xwero 2.515202e-01
# Running CLASS version v3.3.0
# Computing background
# Chose ndf15 as generic_evolver
#  -> age = 12.967267 Gyr
#  -> conformal age = 12951.910148 Mpc
#  -> H0 = 67.000000 km/s/Mpc
#  -> N_eff = 3.044 (summed over all species that are non-relativistic at early times)
#     Scalar field details:
#      -> Omega_scf = 0.05, wished 0.05
# Additional scf parameters used:
# n = 1.000000e+00 m_a = 1.429134e-25 eV, f_a/mpl = 4.000000e-01
#      -> theta_ini = 2.515202e-01 	 phi_ini = 1.006081e-01
#      -> Exact log10(z_c) = 1.033237e+00 	 f_ede = 1.249554e-01 log10 f_ede = -9.032449e-01
#      -> phi(z_c) = 6.025064e-02
#      -> Omega_Lambda = 0.601229, wished 0.601229
#  -> radiation/matter equality at z = 4277.842204
#     corresponding to conformal time = 89.756835 Mpc
#  ---------------------------- Budget equation -----------------------
#  ---> Nonrelativistic Species
# -> Bayrons                        Omega = 0.0486773       , omega = 0.0218513
# -> Cold Dark Matter               Omega = 0.3             , omega = 0.13467
# -> Axion DM                       Omega = 0.05            , omega = 0.022445
#  ---> Relativistic Species
# -> Photons                        Omega = 5.50898e-05     , omega = 2.47298e-05
# -> Ultra-relativistic relics      Omega = 3.80844e-05     , omega = 1.70961e-05
#  ---> Other Content
# -> Cosmological Constant          Omega = 0.601229        , omega = 0.269892
#  ---> Total budgets
#  Radiation                        Omega = 9.31741e-05     , omega = 4.18259e-05
#  Non-relativistic                 Omega = 0.398677        , omega = 0.178966
#  Other Content                    Omega = 0.601229        , omega = 0.269892
#  TOTAL                            Omega = 1               , omega = 0.4489
#  --------------------------------------------------------------------
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2450
#  -> recombination (maximum of visibility function) at z = 1091.873092
#     corresponding to conformal time = 263.704416 Mpc
#     with comoving sound horizon = 136.345830 Mpc
#     angular diameter distance = 11.609953 Mpc
#     sound horizon angle 100*theta_s = 1.074587
#     Thomson optical depth crosses one at z_* = 1089.534514
#     giving an angle 100*theta_* = 1.076094
#  -> baryon drag stops at z = 1061.315394
#     corresponding to conformal time = 269.176559 Mpc
#     with comoving sound horizon rs = 138.831825 Mpc
#  -> reionization with optical depth = 0.047739
#     corresponding to conformal time = 4600.554979 Mpc
# xwero 8.099832e-02
# Running CLASS version v3.3.0
# Computing background
# Chose ndf15 as generic_evolver
#  -> age = 12.967271 Gyr
#  -> conformal age = 12951.906684 Mpc
#  -> H0 = 67.000000 km/s/Mpc
#  -> N_eff = 3.044 (summed over all species that are non-relativistic at early times)
#     Scalar field details:
#      -> Omega_scf = 0.0499997, wished 0.05
# Additional scf parameters used:
# n = 1.000000e+00 m_a = 1.429134e-23 eV, f_a/mpl = 4.000000e-01
#      -> theta_ini = 8.099832e-02 	 phi_ini = 3.239933e-02
#      -> Exact log10(z_c) = 1.033237e+00 	 f_ede = 1.249546e-01 log10 f_ede = -9.032476e-01
#      -> phi(z_c) = 1.952626e-02
#      -> Omega_Lambda = 0.60123, wished 0.601229
#  -> radiation/matter equality at z = 4277.838415
#     corresponding to conformal time = 89.748479 Mpc
#  ---------------------------- Budget equation -----------------------
#  ---> Nonrelativistic Species
# -> Bayrons                        Omega = 0.0486773       , omega = 0.0218513
# -> Cold Dark Matter               Omega = 0.3             , omega = 0.13467
# -> Axion DM                       Omega = 0.05            , omega = 0.022445
#  ---> Relativistic Species
# -> Photons                        Omega = 5.50898e-05     , omega = 2.47298e-05
# -> Ultra-relativistic relics      Omega = 3.80844e-05     , omega = 1.70961e-05
#  ---> Other Content
# -> Cosmological Constant          Omega = 0.601229        , omega = 0.269892
#  ---> Total budgets
#  Radiation                        Omega = 9.31741e-05     , omega = 4.18259e-05
#  Non-relativistic                 Omega = 0.398677        , omega = 0.178966
#  Other Content                    Omega = 0.601229        , omega = 0.269892
#  TOTAL                            Omega = 1               , omega = 0.4489
#  --------------------------------------------------------------------
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2450
#  -> recombination (maximum of visibility function) at z = 1091.873078
#     corresponding to conformal time = 263.696047 Mpc
#     with comoving sound horizon = 136.341008 Mpc
#     angular diameter distance = 11.609958 Mpc
#     sound horizon angle 100*theta_s = 1.074549
#     Thomson optical depth crosses one at z_* = 1089.534504
#     giving an angle 100*theta_* = 1.076056
#  -> baryon drag stops at z = 1061.315386
#     corresponding to conformal time = 269.168191 Mpc
#     with comoving sound horizon rs = 138.827003 Mpc
#  -> reionization with optical depth = 0.047739
#     corresponding to conformal time = 4600.548470 Mpc
# xwero 9.252461e-01
# Running CLASS version v3.3.0
# Computing background
# Chose ndf15 as generic_evolver
#  -> age = 12.967272 Gyr
#  -> conformal age = 12956.697142 Mpc
#  -> H0 = 67.000000 km/s/Mpc
#  -> N_eff = 3.044 (summed over all species that are non-relativistic at early times)
#     Scalar field details:
#      -> Omega_scf = 0.05, wished 0.05
# Additional scf parameters used:
# n = 1.000000e+00 m_a = 1.429134e-28 eV, f_a/mpl = 4.000000e-01
#      -> theta_ini = 9.252461e-01 	 phi_ini = 3.700984e-01
#      -> Exact log10(z_c) = 1.033237e+00 	 f_ede = 1.249554e-01 log10 f_ede = -9.032449e-01
#      -> phi(z_c) = 1.984379e-01
#      -> Omega_Lambda = 0.601229, wished 0.601229
#  -> radiation/matter equality at z = 3986.519666
#     corresponding to conformal time = 97.143419 Mpc
#  ---------------------------- Budget equation -----------------------
#  ---> Nonrelativistic Species
# -> Bayrons                        Omega = 0.0486773       , omega = 0.0218513
# -> Cold Dark Matter               Omega = 0.3             , omega = 0.13467
# -> Axion DM                       Omega = 0.05            , omega = 0.022445
#  ---> Relativistic Species
# -> Photons                        Omega = 5.50898e-05     , omega = 2.47298e-05
# -> Ultra-relativistic relics      Omega = 3.80844e-05     , omega = 1.70961e-05
#  ---> Other Content
# -> Cosmological Constant          Omega = 0.601229        , omega = 0.269892
#  ---> Total budgets
#  Radiation                        Omega = 9.31741e-05     , omega = 4.18259e-05
#  Non-relativistic                 Omega = 0.398677        , omega = 0.178966
#  Other Content                    Omega = 0.601229        , omega = 0.269892
#  TOTAL                            Omega = 1               , omega = 0.4489
#  --------------------------------------------------------------------
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2450
#  -> recombination (maximum of visibility function) at z = 1091.873406
#     corresponding to conformal time = 268.491378 Mpc
#     with comoving sound horizon = 138.865633 Mpc
#     angular diameter distance = 11.609950 Mpc
#     sound horizon angle 100*theta_s = 1.094447
#     Thomson optical depth crosses one at z_* = 1089.536019
#     giving an angle 100*theta_* = 1.095953
#  -> baryon drag stops at z = 1061.316412
#     corresponding to conformal time = 273.963390 Mpc
#     with comoving sound horizon rs = 141.351568 Mpc
#  -> reionization with optical depth = 0.047739
#     corresponding to conformal time = 4605.341986 Mpc
# xwero 4.333571e-01
# Running CLASS version v3.3.0
# Computing background
# Chose ndf15 as generic_evolver
#  -> age = 12.133717 Gyr
#  -> conformal age = 11831.406904 Mpc
#  -> H0 = 67.000000 km/s/Mpc
#  -> N_eff = 3.044 (summed over all species that are non-relativistic at early times)
#     Scalar field details:
#      -> Omega_scf = 0.15, wished 0.15
# Additional scf parameters used:
# n = 1.000000e+00 m_a = 1.429134e-25 eV, f_a/mpl = 4.000000e-01
#      -> theta_ini = 4.333571e-01 	 phi_ini = 1.733428e-01
#      -> Exact log10(z_c) = 1.011622e+00 	 f_ede = 2.999536e-01 log10 f_ede = -5.229459e-01
#      -> phi(z_c) = 1.042799e-01
#      -> Omega_Lambda = 0.501229, wished 0.501229
#  -> radiation/matter equality at z = 5351.103045
#     corresponding to conformal time = 71.776668 Mpc
#  ---------------------------- Budget equation -----------------------
#  ---> Nonrelativistic Species
# -> Bayrons                        Omega = 0.0486773       , omega = 0.0218513
# -> Cold Dark Matter               Omega = 0.3             , omega = 0.13467
# -> Axion DM                       Omega = 0.15            , omega = 0.067335
#  ---> Relativistic Species
# -> Photons                        Omega = 5.50898e-05     , omega = 2.47298e-05
# -> Ultra-relativistic relics      Omega = 3.80844e-05     , omega = 1.70961e-05
#  ---> Other Content
# -> Cosmological Constant          Omega = 0.501229        , omega = 0.225002
#  ---> Total budgets
#  Radiation                        Omega = 9.31741e-05     , omega = 4.18259e-05
#  Non-relativistic                 Omega = 0.498677        , omega = 0.223856
#  Other Content                    Omega = 0.501229        , omega = 0.225002
#  TOTAL                            Omega = 1               , omega = 0.4489
#  --------------------------------------------------------------------
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2450
#  -> recombination (maximum of visibility function) at z = 1094.537084
#     corresponding to conformal time = 247.036820 Mpc
#     with comoving sound horizon = 127.956295 Mpc
#     angular diameter distance = 10.574147 Mpc
#     sound horizon angle 100*theta_s = 1.104560
#     Thomson optical depth crosses one at z_* = 1093.293819
#     giving an angle 100*theta_* = 1.105358
#  -> baryon drag stops at z = 1064.077350
#     corresponding to conformal time = 251.995596 Mpc
#     with comoving sound horizon rs = 130.210146 Mpc
#  -> reionization with optical depth = 0.042983
#     corresponding to conformal time = 4133.386583 Mpc
# xwero 6.081011e-01
# Running CLASS version v3.3.0
# Computing background
# Chose ndf15 as generic_evolver
#  -> age = 11.190182 Gyr
#  -> conformal age = 10621.763540 Mpc
#  -> H0 = 67.000000 km/s/Mpc
#  -> N_eff = 3.044 (summed over all species that are non-relativistic at early times)
#     Scalar field details:
#      -> Omega_scf = 0.3, wished 0.3
# Additional scf parameters used:
# n = 1.000000e+00 m_a = 1.429134e-25 eV, f_a/mpl = 4.000000e-01
#      -> theta_ini = 6.081011e-01 	 phi_ini = 2.432405e-01
#      -> Exact log10(z_c) = 9.690288e-01 	 f_ede = 4.615677e-01 log10 f_ede = -3.357646e-01
#      -> phi(z_c) = 1.472937e-01
#      -> Omega_Lambda = 0.35123, wished 0.351229
#  -> radiation/matter equality at z = 6960.986738
#     corresponding to conformal time = 55.210892 Mpc
#  ---------------------------- Budget equation -----------------------
#  ---> Nonrelativistic Species
# -> Bayrons                        Omega = 0.0486773       , omega = 0.0218513
# -> Cold Dark Matter               Omega = 0.3             , omega = 0.13467
# -> Axion DM                       Omega = 0.3             , omega = 0.13467
#  ---> Relativistic Species
# -> Photons                        Omega = 5.50898e-05     , omega = 2.47298e-05
# -> Ultra-relativistic relics      Omega = 3.80844e-05     , omega = 1.70961e-05
#  ---> Other Content
# -> Cosmological Constant          Omega = 0.351229        , omega = 0.157667
#  ---> Total budgets
#  Radiation                        Omega = 9.31741e-05     , omega = 4.18259e-05
#  Non-relativistic                 Omega = 0.648677        , omega = 0.291191
#  Other Content                    Omega = 0.351229        , omega = 0.157667
#  TOTAL                            Omega = 1               , omega = 0.4489
#  --------------------------------------------------------------------
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2450
#  -> recombination (maximum of visibility function) at z = 1098.087236
#     corresponding to conformal time = 227.526264 Mpc
#     with comoving sound horizon = 118.101850 Mpc
#     angular diameter distance = 9.457154 Mpc
#     sound horizon angle 100*theta_s = 1.136224
#     Thomson optical depth crosses one at z_* = 1098.162334
#     giving an angle 100*theta_* = 1.136176
#  -> baryon drag stops at z = 1067.713643
#     corresponding to conformal time = 231.925525 Mpc
#     with comoving sound horizon rs = 120.102655 Mpc
#  -> reionization with optical depth = 0.037961
#     corresponding to conformal time = 3642.338865 Mpc
# xwero 9.949643e-01
# Running CLASS version v3.3.0
# Computing background
# Chose ndf15 as generic_evolver
#  -> age = 12.967257 Gyr
#  -> conformal age = 12951.898652 Mpc
#  -> H0 = 67.000000 km/s/Mpc
#  -> N_eff = 3.044 (summed over all species that are non-relativistic at early times)
#     Scalar field details:
#      -> Omega_scf = 0.0500008, wished 0.05
# Additional scf parameters used:
# n = 1.000000e+00 m_a = 1.429134e-25 eV, f_a/mpl = 1.000000e-01
#      -> theta_ini = 9.949643e-01 	 phi_ini = 9.949643e-02
#      -> Exact log10(z_c) = 1.033237e+00 	 f_ede = 1.249572e-01 log10 f_ede = -9.032386e-01
#      -> phi(z_c) = 6.386744e-02
#      -> Omega_Lambda = 0.601229, wished 0.601229
#  -> radiation/matter equality at z = 4277.851212
#     corresponding to conformal time = 89.757043 Mpc
#  ---------------------------- Budget equation -----------------------
#  ---> Nonrelativistic Species
# -> Bayrons                        Omega = 0.0486773       , omega = 0.0218513
# -> Cold Dark Matter               Omega = 0.3             , omega = 0.13467
# -> Axion DM                       Omega = 0.05            , omega = 0.022445
#  ---> Relativistic Species
# -> Photons                        Omega = 5.50898e-05     , omega = 2.47298e-05
# -> Ultra-relativistic relics      Omega = 3.80844e-05     , omega = 1.70961e-05
#  ---> Other Content
# -> Cosmological Constant          Omega = 0.601229        , omega = 0.269892
#  ---> Total budgets
#  Radiation                        Omega = 9.31741e-05     , omega = 4.18259e-05
#  Non-relativistic                 Omega = 0.398677        , omega = 0.178966
#  Other Content                    Omega = 0.601229        , omega = 0.269892
#  TOTAL                            Omega = 1               , omega = 0.4489
#  --------------------------------------------------------------------
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2450
#  -> recombination (maximum of visibility function) at z = 1091.873082
#     corresponding to conformal time = 263.704663 Mpc
#     with comoving sound horizon = 136.345983 Mpc
#     angular diameter distance = 11.609943 Mpc
#     sound horizon angle 100*theta_s = 1.074589
#     Thomson optical depth crosses one at z_* = 1089.534544
#     giving an angle 100*theta_* = 1.076096
#  -> baryon drag stops at z = 1061.315413
#     corresponding to conformal time = 269.176796 Mpc
#     with comoving sound horizon rs = 138.831973 Mpc
#  -> reionization with optical depth = 0.047739
#     corresponding to conformal time = 4600.550767 Mpc
# xwero 1.677655e-01
# Running CLASS version v3.3.0
# Computing background
# Chose ndf15 as generic_evolver
#  -> age = 12.967265 Gyr
#  -> conformal age = 12951.908103 Mpc
#  -> H0 = 67.000000 km/s/Mpc
#  -> N_eff = 3.044 (summed over all species that are non-relativistic at early times)
#     Scalar field details:
#      -> Omega_scf = 0.0500001, wished 0.05
# Additional scf parameters used:
# n = 1.000000e+00 m_a = 1.429134e-25 eV, f_a/mpl = 6.000000e-01
#      -> theta_ini = 1.677655e-01 	 phi_ini = 1.006593e-01
#      -> Exact log10(z_c) = 1.033237e+00 	 f_ede = 1.249557e-01 log10 f_ede = -9.032439e-01
#      -> phi(z_c) = 6.011865e-02
#      -> Omega_Lambda = 0.601229, wished 0.601229
#  -> radiation/matter equality at z = 4277.843719
#     corresponding to conformal time = 89.756787 Mpc
#  ---------------------------- Budget equation -----------------------
#  ---> Nonrelativistic Species
# -> Bayrons                        Omega = 0.0486773       , omega = 0.0218513
# -> Cold Dark Matter               Omega = 0.3             , omega = 0.13467
# -> Axion DM                       Omega = 0.05            , omega = 0.022445
#  ---> Relativistic Species
# -> Photons                        Omega = 5.50898e-05     , omega = 2.47298e-05
# -> Ultra-relativistic relics      Omega = 3.80844e-05     , omega = 1.70961e-05
#  ---> Other Content
# -> Cosmological Constant          Omega = 0.601229        , omega = 0.269892
#  ---> Total budgets
#  Radiation                        Omega = 9.31741e-05     , omega = 4.18259e-05
#  Non-relativistic                 Omega = 0.398677        , omega = 0.178966
#  Other Content                    Omega = 0.601229        , omega = 0.269892
#  TOTAL                            Omega = 1               , omega = 0.4489
#  --------------------------------------------------------------------
# Computing thermodynamics using HyRec 2020
#  -> with primordial helium mass fraction Y_He = 0.2450
#  -> recombination (maximum of visibility function) at z = 1091.873066
#     corresponding to conformal time = 263.704379 Mpc
#     with comoving sound horizon = 136.345810 Mpc
#     angular diameter distance = 11.609952 Mpc
#     sound horizon angle 100*theta_s = 1.074587
#     Thomson optical depth crosses one at z_* = 1089.534534
#     giving an angle 100*theta_* = 1.076094
#  -> baryon drag stops at z = 1061.315413
#     corresponding to conformal time = 269.176513 Mpc
#     with comoving sound horizon rs = 138.831801 Mpc
#  -> reionization with optical depth = 0.047739
#     corresponding to conformal time = 4600.554177 Mpc

# %%
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)

ax1.set_xscale('log')
ax1.set_yscale('log')

ax2.set_xscale('log')
ax2.set_yscale('log')

ax3.set_xscale('log')
ax3.set_yscale('log')

ax1.tick_params('x',labelsize=18)
ax1.tick_params('y',labelsize=18)
ax1.set_xlim((1,1000000))
ax1.set_ylim((1e-10,1e15))

ax2.tick_params('x',labelsize=18)
ax2.tick_params('y',labelsize=18)
ax2.set_xlim((1,1000000))
ax2.set_ylim((1e-10,1e15))


ax3.tick_params('x',labelsize=18)
ax3.tick_params('y',labelsize=18)
ax3.set_xlim((1,1000000))
ax3.set_ylim((1e-10,1e15))



ax1.set_xlabel(r"$1+z$", fontsize=20)
ax1.set_ylabel(r"$\rho(z)$", fontsize=20)
ax2.set_xlabel(r"$1+z$", fontsize=20)
# ax2.set_ylabel(r"$\rho(z)$", fontsize=20)
ax3.set_xlabel(r"$1+z$", fontsize=20)
# ax3.set_ylabel(r"$\rho(z)$", fontsize=20)


ax1.plot(1+background_z_1,background_axion_3['(.)rho_scf'],label=r'$\rho_{\rm ax},~m_{\rm ax}=10^5~H_0$')
ax1.plot(1+background_z_1,background_axion_1['(.)rho_scf'],label=r'$\rho_{\rm ax},~m_{\rm ax}=10^8~H_0$')
ax1.plot(1+background_z_1,background_axion_2['(.)rho_scf'],label=r'$\rho_{\rm ax},~m_{\rm ax}=10^{10}~H_0$')
ax1.plot(1+background_z_1,background_axion_1['(.)rho_cdm'],label=r'$\rho_{\rm cdm}$')




ax2.plot(1+background_z_1,background_axion_4['(.)rho_scf'],label=r'$\rho_{\rm ax},~\Omega_{\rm ax}=0.15$')
ax2.plot(1+background_z_1,background_axion_1['(.)rho_scf'],label=r'$\rho_{\rm ax},~\Omega_{\rm ax}=0.05$')
ax2.plot(1+background_z_1,background_axion_5['(.)rho_scf'],label=r'$\rho_{\rm ax},~\Omega_{\rm ax}=0.3$')
ax2.plot(1+background_z_1,background_axion_1['(.)rho_cdm'],label=r'$\rho_{\rm cdm}$')



ax3.plot(1+background_z_1,background_axion_6['(.)rho_scf'],label=r'$\rho_{\rm ax},~f_{\rm ax}=0.2$')
ax3.plot(1+background_z_1,background_axion_1['(.)rho_scf'],label=r'$\rho_{\rm ax},~f_{\rm ax}=0.4$')
ax3.plot(1+background_z_1,background_axion_7['(.)rho_scf'],label=r'$\rho_{\rm ax},~f_{\rm ax}=0.6$')
ax3.plot(1+background_z_1,background_axion_1['(.)rho_cdm'],label=r'$\rho_{\rm cdm}$')

ax1.legend(frameon=False,prop={'size':18},loc='upper left',borderaxespad=0.)
ax2.legend(frameon=False,prop={'size':18},loc='upper left',borderaxespad=0.)
ax3.legend(frameon=False,prop={'size':18},loc='upper left',borderaxespad=0.)

plt.savefig('axion_example_rho.pdf', bbox_inches='tight')

# %%
cosmoLCDM = {
'Omega_cdm':0.3,
'H0':67,
}
LCDM = Class()
LCDM.set({'output': 'mPk', 'z_max_pk': 1, 'P_k_max_h/Mpc': 1.})
LCDM.set(cosmoLCDM)
LCDM.compute()

kk = np.logspace(-4, np.log10(M1.h()), 10000)
Pk_LCDM = [LCDM.pk(ki, 0) for ki in kk]

Pk_axion1 = [M1.pk(ki, 0) for ki in kk]
Pk_axion2 = [M2.pk(ki, 0) for ki in kk]
Pk_axion3 = [M3.pk(ki, 0) for ki in kk]
Pk_axion4 = [M4.pk(ki, 0) for ki in kk]
Pk_axion5 = [M5.pk(ki, 0) for ki in kk]
Pk_axion6 = [M6.pk(ki, 0) for ki in kk]
Pk_axion7 = [M7.pk(ki, 0) for ki in kk]

# %%
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)

ax1.set_xscale('log')
ax1.set_yscale('log')

ax2.set_xscale('log')
ax2.set_yscale('log')

ax3.set_xscale('log')
ax3.set_yscale('log')

ax1.tick_params('x',labelsize=18)
ax1.tick_params('y',labelsize=18)
# ax1.set_xlim((1,1000000))
# ax1.set_ylim((1e-10,1e15))

ax2.tick_params('x',labelsize=18)
ax2.tick_params('y',labelsize=18)
# ax2.set_xlim((1,1000000))
# ax2.set_ylim((1e-10,1e15))


ax3.tick_params('x',labelsize=18)
ax3.tick_params('y',labelsize=18)
# ax3.set_xlim((1,1000000))
# ax3.set_ylim((1e-10,1e15))



ax1.set_xlabel(r"$k$ [$h$/Mpc]", fontsize=20)
ax1.set_ylabel(r"$P(k)$", fontsize=20)
ax2.set_xlabel(r"$k$ [$h$/Mpc]", fontsize=20)
# ax2.set_ylabel(r"$\rho(z)$", fontsize=20)
ax3.set_xlabel(r"$k$ [$h$/Mpc]", fontsize=20)
# ax3.set_ylabel(r"$\rho(z)$", fontsize=20)


ax1.plot(kk,Pk_axion3,label=r'$\rho_{\rm ax},~m_{\rm ax}=10^5~H_0$')
ax1.plot(kk,Pk_axion1,label=r'$\rho_{\rm ax},~m_{\rm ax}=10^8~H_0$')
ax1.plot(kk,Pk_axion2,label=r'$\rho_{\rm ax},~m_{\rm ax}=10^{10}~H_0$')
ax1.plot(kk,Pk_LCDM,label=r'$\rho_{\rm cdm}$')


ax2.plot(kk,Pk_axion4,label=r'$\rho_{\rm ax},~\Omega_{\rm ax}=0.15$')
ax2.plot(kk,Pk_axion1,label=r'$\rho_{\rm ax},~\Omega_{\rm ax}=0.05$')
ax2.plot(kk,Pk_axion5,label=r'$\rho_{\rm ax},~\Omega_{\rm ax}=0.3$')
ax2.plot(kk,Pk_LCDM,label=r'$\rho_{\rm cdm}$')



ax3.plot(kk,Pk_axion6,label=r'$\rho_{\rm ax},~f_{\rm ax}=0.4$')
ax3.plot(kk,Pk_axion1,label=r'$\rho_{\rm ax},~f_{\rm ax}=0.2$')
ax3.plot(kk,Pk_axion7,label=r'$\rho_{\rm ax},~f_{\rm ax}=0.6$')
ax3.plot(kk,Pk_LCDM,label=r'$\rho_{\rm cdm}$')


ax1.legend(frameon=False,prop={'size':18},loc='lower left',borderaxespad=0.)
ax2.legend(frameon=False,prop={'size':18},loc='lower left',borderaxespad=0.)
ax3.legend(frameon=False,prop={'size':18},loc='lower left',borderaxespad=0.)

plt.savefig('axion_example_pk.pdf', bbox_inches='tight')
